# %%
import torch as t
import os 
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env =gym.make('CartPole-v0')

# %%
episodes=5  #loop the environment 5 times
for episode in range(1,episodes+1):
    state = env.reset() # set init the environment,state, get the observation 
    done = False
    score =0

    while not done:
       env.render()
       action = env.action_space.sample()  # space of actions is Discrete(2)=0 or 1
       n_state,reward,done,info=env.step(action)
       score+=reward
    print('Episode:{} score{}'.format(episode,score))
env.close()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
##undetstanding the environment

# %%
env.action_space #two actions 0 and 1
# Out:
# Discrete(2)

# %%
env.action_space.sample()  # 0 ----push cart to the left
# 1----push cart to the right
# Out:
# 0

# %%
env.observation_space   # Box(4)  4 observations: #cart position
                                                  #cart velocity
                                                  #pole angle
                                                  #pole angular velocity
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([-1.6168649e+00,  2.1736372e+38, -1.7665635e-01,  2.1950139e+38],
#       dtype=float32)

# %%
env.step(1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/px/8_6897y52cl_kz9fkqt6xpzh0000gn/T/ipykernel_84737/2174298932.py in <module>
# ----> 1 env.step(1)
#
# ~/miniforge3/envs/tensorflow24/lib/python3.8/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      13
#      14     def step(self, action):
# ---> 15         assert (
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
#
# AssertionError: Cannot call env.step() before calling reset()

# %%
#####training

# %%
log_path=os.path.join('nicho_reinforecement','log')

# %%
log_path
# Out:
# 'nicho_reinforecement/log'

# %%
import tensorboard

env = gym.make('CartPole-v0')
env=DummyVecEnv([lambda:env])
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to nicho_reinforecement/log/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 622  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1039       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00876465 |
# |    clip_fraction        | 0.0729     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0.00169    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.51       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 52.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010837466 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.089       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 36.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1595       |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00861375 |
# |    clip_fraction        | 0.092      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.8       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0181    |
# |    value_loss           | 57.8       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1789         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0055832346 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.624       |
# |    explained_variance   | 0.341        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 57.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1946        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008983414 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 59.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009394238 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2193        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008974697 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 68.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2285         |
# |    iterations           | 9            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0071846014 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00645     |
# |    value_loss           | 40.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2369         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036126066 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.44         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00647     |
# |    value_loss           | 28.6         |
# ------------------------------------------

# %%
#####################################save and reload model###############################################

# %%
PPO_Path=os.path.join('save_model','PPO_model_cartpole')  #save_model必须和project放在同一个目录下

# %%
model.save(PPO_Path)

# %%
del model

# %%
PPO_Path
# Out:
# 'save_model/PPO_model_cartpole'

# %%
model = PPO.load(PPO_Path,env=env)

# %%
model.learn(total_timesteps=10000)
# Out:
# Logging to nicho_reinforecement/log/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 7528 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4778         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0064823716 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.28         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00617     |
# |    value_loss           | 27.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4211         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0027571702 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.0618       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 45.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4012         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0055633066 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.718        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.395        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 3.65         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3904         |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0020426908 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.0433       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.342        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00054     |
# |    value_loss           | 2.36         |
# ------------------------------------------

# %%
#############################################Evaluation######################################

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=False)  #render=False 就不会展示图像视频
# Out:
# /Users/sampson/miniforge3/envs/tensorflow24/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %%
############################### Test Model ###################################

# %%
episodes=5
for episode in range(1,episodes+1):
    obs = env.reset()
    done = False
    socre=0

    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs,reward,done,info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
############################ Adding a callback to training Stage#########################
training_log_path=os.path.join('nicho_reinforecement','log','OPP_2')

# %%
from stable_baselines3.common.callbacks import EvalCallback,StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('save_model')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)
eval_callback = EvalCallback(env,callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=training_log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 80 from C header, got 96 from PyObject
# Logging to nicho_reinforecement/log/OPP_2/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | 23.7     |
# | time/              |          |
# |    fps             | 600      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | 28.7        |
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008605739 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00825     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.75        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 55.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | 37.8        |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008319784 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0705      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 39.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | 47.4        |
# | time/                   |             |
# |    fps                  | 1578        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008876521 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.255       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 53.4        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.008917019 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 65.3        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200
# /Users/sampson/miniforge3/envs/tensorflow24/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
#####################Changing Polices######################

# %%
net_arch=[dict(pi=[128,128,128,128],vf=[128,128,128,128])]
model = PPO('MlpPolicy',env,verbose=1,tensorboard_log=training_log_path,policy_kwargs={'net_arch':net_arch})

#net_arch 自己设计的神经网络
#PPO 使用多项神经元MlpPoliy 然后导入net_arch
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200000,callback=eval_callback)
# Out:
# Logging to nicho_reinforecement/log/OPP_2/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    fps             | 5957     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.6         |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 3158         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0138332285 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | -0.00121     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.78         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0197      |
# |    value_loss           | 19.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42         |
# |    ep_rew_mean          | 42         |
# | time/                   |            |
# |    fps                  | 2753       |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01749491 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.645     |
# |    explained_variance   | 0.428      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.2       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0369    |
# |    value_loss           | 27.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.2        |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 2607        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013362587 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 47          |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.016594984 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.86        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 43.6        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.4     |
# |    ep_rew_mean     | 74.4     |
# | time/              |          |
# |    fps             | 2445     |
# |    iterations      | 5        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 10240    |
# ---------------------------------
# /Users/sampson/miniforge3/envs/tensorflow24/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.4        |
# |    ep_rew_mean          | 90.4        |
# | time/                   |             |
# |    fps                  | 2409        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015515177 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 2375         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0123319635 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.512        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 9.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 2358        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010616294 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.777       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 5.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 2334         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038574846 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.452        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 4.52         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.006564982 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.704       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 10.1        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 159      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    fps             | 2287     |
# |    iterations      | 10       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 20480    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 170          |
# |    ep_rew_mean          | 170          |
# | time/                   |              |
# |    fps                  | 2283         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070975493 |
# |    clip_fraction        | 0.0857       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.209        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 1.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | 184          |
# | time/                   |              |
# |    fps                  | 2273         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0025033928 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00253      |
# |    value_loss           | 12.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 2263        |
# |    iterations           | 13          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005439395 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 9.25        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 199        |
# |    ep_rew_mean          | 199        |
# | time/                   |            |
# |    fps                  | 2255       |
# |    iterations           | 14         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00817659 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.48      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.564      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0139    |
# |    value_loss           | 1.59       |
# ----------------------------------------
# Eval num_timesteps=30000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.008041902 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0599      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.494       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    fps             | 2225     |
# |    iterations      | 15       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 30720    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2226        |
# |    iterations           | 16          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012143973 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.43       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0715      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 0.305       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2220        |
# |    iterations           | 17          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006882457 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | -0.125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0777      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00115     |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 196          |
# |    ep_rew_mean          | 196          |
# | time/                   |              |
# |    fps                  | 2222         |
# |    iterations           | 18           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0107441675 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0413       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 0.143        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 2223        |
# |    iterations           | 19          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.002740032 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.0394      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 68.6        |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 200       |
# |    mean_reward          | 200       |
# | time/                   |           |
# |    total_timesteps      | 40000     |
# | train/                  |           |
# |    approx_kl            | 0.0030041 |
# |    clip_fraction        | 0.00547   |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.419    |
# |    explained_variance   | 0.407     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.88      |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.00294  |
# |    value_loss           | 13.1      |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    fps             | 2203     |
# |    iterations      | 20       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 40960    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 2206         |
# |    iterations           | 21           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0044251513 |
# |    clip_fraction        | 0.0626       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.273        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 1.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 2205         |
# |    iterations           | 22           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0059785387 |
# |    clip_fraction        | 0.0773       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0437       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00869     |
# |    value_loss           | 0.216        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2207        |
# |    iterations           | 23          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007618624 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | -0.103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00639     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 0.0394      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2209        |
# |    iterations           | 24          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006481993 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | -0.208      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000641   |
# |    value_loss           | 0.0248      |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.008046332 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.331      |
# |    explained_variance   | -0.0338     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000904    |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 198      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    fps             | 2198     |
# |    iterations      | 25       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 51200    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2199        |
# |    iterations           | 26          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011285864 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00412     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00309     |
# |    value_loss           | 0.0115      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 2201        |
# |    iterations           | 27          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005852408 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.333      |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.344       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 5.2         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2201         |
# |    iterations           | 28           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0151315555 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00316     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00248      |
# |    value_loss           | 0.00758      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 201         |
# | time/                   |             |
# |    fps                  | 2203        |
# |    iterations           | 29          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004561098 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | -0.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000263   |
# |    value_loss           | 0.00468     |
# -----------------------------------------
# Eval num_timesteps=60000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.010644043 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.354      |
# |    explained_variance   | -0.0166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00284     |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2192     |
# |    iterations      | 30       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 61440    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2191        |
# |    iterations           | 31          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008190384 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.373      |
# |    explained_variance   | 0.0165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00807    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00166     |
# |    value_loss           | 0.00227     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2188        |
# |    iterations           | 32          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007368845 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | -0.0125     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00325     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000819   |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2191         |
# |    iterations           | 33           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0053349673 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | -0.0272      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00703     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.0017       |
# |    value_loss           | 0.00125      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2192        |
# |    iterations           | 34          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007642561 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | -0.179      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00165     |
# |    value_loss           | 0.000957    |
# -----------------------------------------
# Eval num_timesteps=70000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0023943996 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.0809       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00335      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 0.000604     |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2185     |
# |    iterations      | 35       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 71680    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2186         |
# |    iterations           | 36           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0038658604 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.0653       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0114       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00105      |
# |    value_loss           | 0.000486     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2186         |
# |    iterations           | 37           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0042060073 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.443       |
# |    explained_variance   | -0.0264      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00943     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -9.99e-06    |
# |    value_loss           | 0.00033      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2188        |
# |    iterations           | 38          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003936883 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | -0.0727     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00212     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.000977    |
# |    value_loss           | 0.00023     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2188         |
# |    iterations           | 39           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0022104909 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | -0.0553      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00484     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000895     |
# |    value_loss           | 0.000204     |
# ------------------------------------------
# Eval num_timesteps=80000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.007646245 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | -0.0659     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000679    |
# |    value_loss           | 0.000138    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2181     |
# |    iterations      | 40       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 81920    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2181         |
# |    iterations           | 41           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0053720796 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | -0.106       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00885      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000723     |
# |    value_loss           | 0.000122     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2181         |
# |    iterations           | 42           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0023853623 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.00449      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 0.000103     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2182        |
# |    iterations           | 43          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007565587 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | -0.0711     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.002      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.000333    |
# |    value_loss           | 9.64e-05    |
# -----------------------------------------
# Eval num_timesteps=90000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 0.005889324 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | -0.897      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0032     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -3.32e-05   |
# |    value_loss           | 4.56e-05    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2175     |
# |    iterations      | 44       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 90112    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | 200        |
# | time/                   |            |
# |    fps                  | 2177       |
# |    iterations           | 45         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01000414 |
# |    clip_fraction        | 0.0568     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.429     |
# |    explained_variance   | -0.0981    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00622    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00137    |
# |    value_loss           | 3.06e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2179         |
# |    iterations           | 46           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0047519086 |
# |    clip_fraction        | 0.0674       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | -0.0871      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00428     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00108      |
# |    value_loss           | 2e-05        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2180        |
# |    iterations           | 47          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006785077 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.424      |
# |    explained_variance   | -0.0848     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00661     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 6.79e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2181        |
# |    iterations           | 48          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009953744 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.415      |
# |    explained_variance   | -0.306      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0168     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 1.84e-05    |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.008772567 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | -0.0491     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000529   |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.000178    |
# |    value_loss           | 1.6e-05     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2176     |
# |    iterations      | 49       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 100352   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2172        |
# |    iterations           | 50          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008179521 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | -0.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00571    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 6.6e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2174         |
# |    iterations           | 51           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0033931173 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.413       |
# |    explained_variance   | -0.109       |
# |    learning_rate        | 0.0003       |
# ...
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.005444511 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | -0.242      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00219     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.000309   |
# |    value_loss           | 9.98e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2187        |
# |    iterations           | 83          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.015809052 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | 0.0271      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00457    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.00133     |
# |    value_loss           | 0.000461    |
# -----------------------------------------
# Eval num_timesteps=170000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 170000      |
# | train/                  |             |
# |    approx_kl            | 0.014606653 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 0.0331      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0243      |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.000607    |
# |    value_loss           | 1.71e-05    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2184     |
# |    iterations      | 84       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 172032   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2185        |
# |    iterations           | 85          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.008870199 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.173      |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00586     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 0.00162     |
# |    value_loss           | 0.000139    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2186        |
# |    iterations           | 86          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008069383 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00563     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00229     |
# |    value_loss           | 9.59e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2187         |
# |    iterations           | 87           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0039535603 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.201       |
# |    explained_variance   | -0.00136     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0251       |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.00289      |
# |    value_loss           | 1.41e-06     |
# ------------------------------------------
# Eval num_timesteps=180000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 180000       |
# | train/                  |              |
# |    approx_kl            | 0.0055308007 |
# |    clip_fraction        | 0.0648       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.203       |
# |    explained_variance   | 0.0153       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0264       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000969     |
# |    value_loss           | 7.87e-07     |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2185     |
# |    iterations      | 88       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 180224   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | 200       |
# | time/                   |           |
# |    fps                  | 2186      |
# |    iterations           | 89        |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 182272    |
# | train/                  |           |
# |    approx_kl            | 0.0070725 |
# |    clip_fraction        | 0.0485    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.2      |
# |    explained_variance   | -0.0614   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00417   |
# |    n_updates            | 880       |
# |    policy_gradient_loss | 0.00137   |
# |    value_loss           | 0.000494  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2187        |
# |    iterations           | 90          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004270807 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.211      |
# |    explained_variance   | -0.0219     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00278    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | 0.00538     |
# |    value_loss           | 2.74e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2188        |
# |    iterations           | 91          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008299988 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.238      |
# |    explained_variance   | -0.00409    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00283     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00346     |
# |    value_loss           | 1.15e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2189        |
# |    iterations           | 92          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011635944 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.245      |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000369    |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 2.5e-06     |
# -----------------------------------------
# Eval num_timesteps=190000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 190000       |
# | train/                  |              |
# |    approx_kl            | 0.0062335124 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -0.182       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00258     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | 0.00116      |
# |    value_loss           | 1.3e-05      |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2187     |
# |    iterations      | 93       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 190464   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2188         |
# |    iterations           | 94           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0045727333 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.305       |
# |    explained_variance   | -0.771       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00846      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.00139      |
# |    value_loss           | 8.38e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2189         |
# |    iterations           | 95           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0064594895 |
# |    clip_fraction        | 0.0762       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | -0.0967      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00763      |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.00182      |
# |    value_loss           | 1.91e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 2190        |
# |    iterations           | 96          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.024812557 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.354      |
# |    explained_variance   | -0.0476     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00175     |
# |    value_loss           | 6.35e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 2190         |
# |    iterations           | 97           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0058705844 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -0.0622      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00331     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.00101      |
# |    value_loss           | 2.7e-05      |
# ------------------------------------------
# Eval num_timesteps=200000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 200000       |
# | train/                  |              |
# |    approx_kl            | 0.0089989975 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | -0.207       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00858     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.00236      |
# |    value_loss           | 1.64e-06     |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2188     |
# |    iterations      | 98       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 200704   |
# ---------------------------------

# %%
#########################################Using an Alternate Algorithm########################

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy',env,verbose=1,tensorboard_log=training_log_path)
model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to nicho_reinforecement/log/OPP_2/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8962     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 12823    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 13207    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 13989    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 15982    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 15743    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 514      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 15661    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 15713    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 664      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 15337    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 15450    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 810      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 15557    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 896      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 15759    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 15806    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 16075    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.376    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 16255    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 16384    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 16561    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 16591    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 16715    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 16852    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 16901    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.0685   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 16923    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 17002    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 17061    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 17009    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 17274    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 17327    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 17292    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 17323    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 17314    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 17390    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 17405    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 17420    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 17352    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 17350    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 17276    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 17282    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 17361    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 17295    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 17378    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 17378    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 17418    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 17320    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 17325    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 17353    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 17399    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 17422    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 17455    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 17470    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 17465    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 17503    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 17550    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 17569    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 17571    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 17638    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 17575    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 17661    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 17694    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 17627    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 17812    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 17823    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 17817    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 17880    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 17953    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 17991    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 17998    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 18017    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 18061    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 18032    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 18122    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 18113    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 18174    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 18144    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 18155    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 18156    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 18168    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 18175    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 18203    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 18220    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7097     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.5     |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 18231    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 18238    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 18251    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7366     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 18312    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 18273    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 18317    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 18309    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 18307    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 18290    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 18301    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 18336    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 18339    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 18339    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 18284    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 18165    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 18140    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 18085    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 17990    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 17897    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 17813    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 17807    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 17813    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 17818    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 17807    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9110     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 17796    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 17829    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 17827    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 17793    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 17824    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 17769    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 17781    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 17785    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 17803    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 17814    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 17704    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 17696    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 17710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 17733    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 17750    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 17723    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10555    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 17745    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 17774    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 17747    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 17809    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 17829    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# ...
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 16748    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 16757    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 16760    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 16752    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 16750    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 16728    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 16724    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 16748    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.5     |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 16753    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.3     |
# |    ep_rew_mean      | 23.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 16745    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 16759    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 16751    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 16747    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 16755    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.3     |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 16785    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17645    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.6     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 16802    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 16783    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 16774    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 16804    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 16820    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 16803    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.7     |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 16831    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 16845    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 16865    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.3     |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 16796    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24       |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 16790    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.1     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 16686    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 16661    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.9     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 16570    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 16580    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 16526    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 16518    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 16515    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 16514    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19255    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.9     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 16515    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 16519    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 16522    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 16530    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 16544    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 16550    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 16557    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 16567    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19946    |
# ----------------------------------
